# %%
# Test 1: Basic Python
import sys
print(f'Python version: {sys.version}')
print('Hello from Docker container!')

# %%
# Test 2: Simple math
x = 10
y = 20
result = x + y
print(f'{x} + {y} = {result}')

# %%
# Test 3: List and dict operations
numbers = [1, 2, 3, 4, 5]
squares = [n**2 for n in numbers]
print(f'Numbers: {numbers}')
print(f'Squares: {squares}')

data = {'name': 'Test', 'value': 42}
print(f'Data: {data}')
